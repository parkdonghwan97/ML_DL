# %%
import tensorflow as tf
import numpy as np
import pandas as pd

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/test.csv', header=None)
df.columns=['q1','q2','mid','final']
df
# Out:
#     q1  q2  mid  final
# 0   73  80   75    152
# 1   93  88   93    185
# 2   89  91   90    180
# 3   96  98  100    196
# 4   73  66   70    142
# 5   53  46   55    101
# 6   69  74   77    149
# 7   47  56   60    115
# 8   87  79   90    175
# 9   79  70   88    164
# 10  69  70   73    141
# 11  70  65   74    141
# 12  93  95   91    184
# 13  79  80   73    152
# 14  70  73   78    148
# 15  93  89   96    192
# 16  78  75   68    147
# 17  81  90   93    183
# 18  88  92   86    177
# 19  78  83   77    159
# 20  82  86   90    177
# 21  86  82   89    175
# 22  78  83   85    175
# 23  76  83   71    149
# 24  96  93   95    192

# %%
http://localhost:8890/notebooks/13.%EB%8B%A4%EC%A4%91%EC%84%A0%ED%98%95(%EC%BC%80%EB%9D%BC%EC%8A%A4).ipynb#x_data = df.iloc[:,:-1].values #특성데이터 추출
y_data = df.iloc[:, [-1]].values

# %%
dense = Dense( units=1, input_dim=3 ) # w:3x1,b:1 초기값...
model = Sequential( [dense] )
model.compile( loss='mse', optimizer=Adam(0.1) )
h = model.fit( x_data, y_data, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 182ms/step - loss: 24921.2227
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 17835.3613
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 11976.3086
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 7348.2749
# Epoch 5/500
# 1/1 [==============================] - 0s 998us/step - loss: 3928.1826
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1654.6776
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 417.1939
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 48.7187
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 328.8171
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1002.7010
# Epoch 11/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1815.6595
# Epoch 12/500
# ...

# %%
# q1:80, q2:90, mid:90 최종점수를 예측하시요
model.predict( [[80,90,90]] )
# Out:
# array([[174.8546]], dtype=float32)

# %%
w,b = dense.get_weights()

# %%
w
# Out:
# array([[0.78197044],
#        [0.7507158 ],
#        [0.48876297]], dtype=float32)

# %%
b
# Out:
# array([0.74388003], dtype=float32)

# %%
1. 상관관계
2. 정규화
3. 다중공선성
